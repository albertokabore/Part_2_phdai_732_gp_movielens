# %% [markdown]
# # PhDAI 732 Group 5, Part 2: MovieLens 100K recommender
#
# Thin driver. All logic lives in `src/`. Run the cells in order.

# %%
# 1. Clone the repo. Set REPO to the group's GitHub URL.
REPO = "https://github.com/jecollier041/phdai_732_gp_movielens.git"   # <-- confirm
DIR = REPO.rstrip("/").split("/")[-1].removesuffix(".git")
# !git clone -q {REPO}
# %cd {DIR}

# %%
# 2. Install Surprise and confirm it imports. If this cell errors on NumPy,
#    run:  !pip install -q "numpy<2" scikit-surprise
#    then Runtime > Restart session, and rerun from cell 1.
# !pip install -q scikit-surprise
import surprise, numpy, sys
print("surprise", surprise.__version__, "| numpy", numpy.__version__, "| python", sys.version.split()[0])

# %%
# 3. Run the pipeline. The expanded grid search takes several minutes on Colab's CPU.
#    For a fast wiring check only, use:  !python run_all.py --quick   (never cite those numbers)
# !python run_all.py

# %%
# 4. Every number the report needs, with the file it came from.
from IPython.display import Markdown, display
display(Markdown(open("results/KEY_NUMBERS.md").read()))

# %%
# 5. Figures.
from pathlib import Path
from IPython.display import Image
for p in sorted(Path("figures").glob("*.png")):
    print(p.name); display(Image(filename=str(p), width=720))

# %%
# 6. Commit results back so drafters read the same numbers. Needs push access.
# !git add results figures src/config.py && git commit -m "Full Part 2 run" && git push
